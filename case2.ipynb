# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a243-coder/python-record/blob/main/case2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q2="""1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s marks"""
print(Q2)
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for ch in set(input_str):
    # The line 't i t t t( h)' was syntactically incorrect and has been commented out.
    # t i t t t( h)
    count = input_str.count(ch)
    print(f"'{ch}' appears {count} times")
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s marks
# Enter a string: harsha
# Not Palindrome
# 'h' appears 2 times
# 'a' appears 2 times
# 'r' appears 1 times
# 's' appears 1 times
